# %%
import datetime as dt
import numpy as np
import pandas as pd

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///../db/apache.sqlite")
base= automap_base()
base.prepare(engine, reflect=True)
inspector = inspect(engine)
log_table = base.classes.access_response
session = Session(engine)

# %%
admin_query = 'select * from access_response where URL like "%admin"'
admin_results = pd.read_sql_query(admin_query, session.bind)

# %%
len(admin_results)
# Out:
# 41

# %%
admin_results
# Out:
#        id              ip             DateTime  TimeZone Method  \
# 0    3704    5.101.156.30  2018-02-27 05:42:37  GMT-0800    GET
# 1    3851   51.255.82.192  2018-03-01 20:31:03  GMT-0800    GET
# 2    3853   51.255.82.192  2018-03-01 20:31:04  GMT-0800    GET
# 3    3854   51.255.82.192  2018-03-01 20:31:04  GMT-0800    GET
# 4    3855   51.255.82.192  2018-03-01 20:31:04  GMT-0800    GET
# 5    3856   51.255.82.192  2018-03-01 20:31:05  GMT-0800    GET
# 6    3857   51.255.82.192  2018-03-01 20:31:05  GMT-0800    GET
# 7    3860   51.255.82.192  2018-03-01 20:31:06  GMT-0800    GET
# 8    3865   51.255.82.192  2018-03-01 20:31:15  GMT-0800    GET
# 9    3866   51.255.82.192  2018-03-01 20:31:15  GMT-0800    GET
# 10   3867   51.255.82.192  2018-03-01 20:31:16  GMT-0800    GET
# 11   3868   51.255.82.192  2018-03-01 20:31:16  GMT-0800    GET
# 12   6675    23.102.11.50  2015-12-08 15:29:14  GMT-0800    GET
# 13  12674   188.124.17.47  2015-11-03 17:02:53  GMT-0800    GET
# ...

# %%
php_query = 'select * from access_response where URL like "%php"'
php_results = pd.read_sql_query(php_query, session.bind)

# %%
len(php_results)
# Out:
# 3223

# %%
php_results
# Out:
#          id               ip             DateTime  TimeZone Method  \
# 0        43    46.243.189.99  2018-04-08 22:23:38  GMT-0700    GET
# 1        44    46.243.189.99  2018-04-08 22:23:38  GMT-0700    GET
# 2        45    46.243.189.99  2018-04-08 22:23:38  GMT-0700    GET
# 3        46    46.243.189.99  2018-04-08 22:23:39  GMT-0700    GET
# 4        47    46.243.189.99  2018-04-08 22:23:39  GMT-0700    GET
# 5       118  198.167.140.177  2018-04-10 01:10:39  GMT-0700    GET
# 6       119  198.167.140.177  2018-04-10 01:10:39  GMT-0700    GET
# 7       120  198.167.140.177  2018-04-10 01:10:39  GMT-0700    GET
# 8       121  198.167.140.177  2018-04-10 01:10:39  GMT-0700    GET
# 9       122  198.167.140.177  2018-04-10 01:10:39  GMT-0700    GET
# 10      141    80.211.174.61  2018-04-10 14:10:50  GMT-0700    GET
# 11      214    80.211.173.62  2018-04-11 10:39:21  GMT-0700    GET
# 12      215    80.211.173.62  2018-04-11 10:39:21  GMT-0700    GET
# ...

# %%
login_query = 'select * from access_response where URL like "%login"'
login_results = pd.read_sql_query(login_query, session.bind)

# %%
login_results
# Out:
#        id              ip             DateTime  TimeZone Method  \
# 0    3826   51.255.82.192  2018-03-01 20:30:55  GMT-0800    GET
# 1   14410   183.60.244.46  2015-10-30 22:32:30  GMT-0700    GET
# 2   14411   183.60.244.46  2015-10-30 22:32:31  GMT-0700    GET
# 3   16216  183.60.243.189  2015-10-09 06:23:20  GMT-0700    GET
# 4   16217  183.60.243.189  2015-10-09 06:23:20  GMT-0700    GET
# 5   17858   94.190.79.198  2015-09-18 06:08:43  GMT-0700    GET
# 6   17913   94.190.79.198  2015-09-19 02:41:44  GMT-0700    GET
# 7   18863   183.60.244.44  2015-09-03 21:50:26  GMT-0700    GET
# 8   18864   183.60.244.44  2015-09-03 21:50:27  GMT-0700    GET
# 9   22385   98.110.41.202  2015-07-02 14:09:14  GMT-0700    GET
# 10  22386   98.110.41.202  2015-07-02 14:09:14  GMT-0700    GET
# 11  22387   98.110.41.202  2015-07-02 14:09:14  GMT-0700    GET
# 12  22458   98.110.41.202  2015-07-04 00:36:00  GMT-0700    GET
# 13  22459   98.110.41.202  2015-07-04 00:36:01  GMT-0700    GET
# ...

# %%
#pma_query = 'select * from access_response where URL like "%pma%"'
#pma_results = pd.read_sql_query(pma_query, session.bind)

# %%
#len(pma_results)

# %%
#pma_results

# %%
ramble_query = 'select * from access_response where URL like "%ramble%" and DateTime like "2018%"'
ramble_results = pd.read_sql_query(ramble_query, session.bind)

# %%
len(ramble_results)
# Out:
# 158

# %%
ramble_results
# Out:
#        id              ip             DateTime  TimeZone Method  \
# 0     228  216.244.66.229  2018-04-11 16:26:38  GMT-0700    GET
# 1     280    217.69.133.4  2018-04-13 01:28:51  GMT-0700    GET
# 2     281    217.69.133.2  2018-04-13 01:31:02  GMT-0700    GET
# 3     526  216.244.66.229  2018-04-02 08:42:22  GMT-0700    GET
# 4     538  216.244.66.246  2018-04-02 14:25:14  GMT-0700    GET
# 5     539  216.244.66.246  2018-04-02 14:27:15  GMT-0700    GET
# 6     544  185.234.218.86  2018-04-02 19:02:30  GMT-0700    GET
# 7     714   92.100.184.21  2018-04-05 05:20:16  GMT-0700    GET
# 8     718  216.244.66.246  2018-04-05 07:02:55  GMT-0700    GET
# 9     721  216.244.66.246  2018-04-05 08:22:20  GMT-0700    GET
# 10    739  216.244.66.194  2018-04-05 16:38:39  GMT-0700    GET
# 11    786   91.237.41.157  2018-04-06 08:27:25  GMT-0700    GET
# 12    787   91.237.41.157  2018-04-06 08:27:25  GMT-0700    GET
# 13    788   91.237.41.157  2018-04-06 08:27:25  GMT-0700    GET
# ...

# %%
port_query = 'select * from access_response where URL like "%port%"'
port_results = pd.read_sql_query(port_query, session.bind)

# %%
len(port_results)
# Out:
# 276

# %%
ua_script_query = 'select * from access_response where UserAgent like "%urll%" or UserAgent like "%curl%"'
ua_script_results = pd.read_sql_query(ua_script_query, session.bind)

# %%
len(ua_script_results)
# Out:
# 705

# %%
ua_script_results
# Out:
#         id               ip             DateTime  TimeZone Method  \
# 0       26    24.48.238.249  2018-04-08 13:10:40  GMT-0700    GET
# 1       27    24.48.238.249  2018-04-08 13:35:08  GMT-0700    GET
# 2       32   185.207.205.93  2018-04-08 18:53:52  GMT-0700   HEAD
# 3       33   185.207.205.93  2018-04-08 18:53:53  GMT-0700    GET
# 4       55    114.147.72.16  2018-04-09 01:11:06  GMT-0700    GET
# 5       92   185.207.205.93  2018-04-09 19:57:51  GMT-0700   HEAD
# 6       93   185.207.205.93  2018-04-09 19:57:52  GMT-0700    GET
# 7      136  135.245.115.103  2018-04-10 13:03:14  GMT-0700    GET
# 8      151    12.156.67.130  2018-04-10 15:44:47  GMT-0700    GET
# 9      159   185.207.205.93  2018-04-10 20:59:59  GMT-0700   HEAD
# 10     160   185.207.205.93  2018-04-10 20:59:59  GMT-0700    GET
# 11     167    114.147.72.16  2018-04-11 01:10:29  GMT-0700    GET
# 12     224  140.116.245.162  2018-04-11 14:56:07  GMT-0700    GET
# ...

# %%
ua_script_results_no_200 = ua_script_results[(ua_script_results.ResponseCode !='200')]

# %%
ua_script_results_no_200
# Out:
#         id               ip             DateTime  TimeZone Method  \
# 0       26    24.48.238.249  2018-04-08 13:10:40  GMT-0700    GET
# 1       27    24.48.238.249  2018-04-08 13:35:08  GMT-0700    GET
# 4       55    114.147.72.16  2018-04-09 01:11:06  GMT-0700    GET
# 7      136  135.245.115.103  2018-04-10 13:03:14  GMT-0700    GET
# 8      151    12.156.67.130  2018-04-10 15:44:47  GMT-0700    GET
# 11     167    114.147.72.16  2018-04-11 01:10:29  GMT-0700    GET
# 12     224  140.116.245.162  2018-04-11 14:56:07  GMT-0700    GET
# 15     270    128.62.160.14  2018-04-12 15:45:44  GMT-0700    GET
# 18     282  119.247.135.127  2018-04-13 01:55:00  GMT-0700    GET
# 23     540    12.156.67.130  2018-04-02 14:59:16  GMT-0700    GET
# 25     560   103.81.106.250  2018-04-03 04:44:33  GMT-0700    GET
# 28     668  181.140.168.184  2018-04-04 12:29:52  GMT-0700    GET
# 29     673  181.140.168.184  2018-04-04 13:11:15  GMT-0700    GET
# ...

# %%
len(ua_script_results)
# Out:
# 705
