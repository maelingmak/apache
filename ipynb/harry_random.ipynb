# %%
#Import dependencies
import numpy
import pandas as pd
import requests
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect

# %%
engine = create_engine("sqlite:///../db/apache.sqlite")
Base = automap_base()
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()

# %%
session = Session(engine)
for row in session.query(Base.classes.access_response).limit(5).all():
    print(row)

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['access_response']

# %%
columns = inspector.get_columns("access_response")
param = []
for column in columns:
    print(column["name"], column["type"])
    param.append(f"table.{column['name']}")
param
# Out:
# id INTEGER
# access_id INTEGER
# ip TEXT
# DateTime TEXT
# TimeZone TEXT
# Method TEXT
# URL TEXT
# ResponseCode TEXT
# Referer TEXT
# BytesSent TEXT
# UserAgent TEXT
# latitude FLOAT
# longitude FLOAT
# ['table.id',
#  'table.access_id',
#  'table.ip',
#  'table.DateTime',
#  'table.TimeZone',
#  'table.Method',
#  'table.URL',
#  'table.ResponseCode',
#  'table.Referer',
#  'table.BytesSent',
#  'table.UserAgent',
#  'table.latitude',
#  'table.longitude']

# %%
table = Base.classes.access_response

# %%
params = {table.id, table.access_id, table.ip, 
          table.DateTime, table.TimeZone,
          table.Method, table.URL, table.ResponseCode,
          table.Referer, table.BytesSent, table.UserAgent,
          table.latitude, table.longitude}

# %%
results = session.query(table.id, table.access_id, table.ip, 
          table.DateTime, table.TimeZone,
          table.Method, table.URL, table.ResponseCode,
          table.Referer, table.BytesSent, table.UserAgent,
          table.latitude, table.longitude).all()
df = pd.DataFrame(results)
df
# Out:
#           id access_id               ip             DateTime  TimeZone  \
# 0          1      None     62.170.2.205  2018-04-08 07:19:25  GMT-0700
# 1          2      None     62.170.2.205  2018-04-08 07:19:25  GMT-0700
# 2          3      None     62.170.2.205  2018-04-08 07:19:25  GMT-0700
# 3          4      None     62.170.2.205  2018-04-08 07:19:26  GMT-0700
# 4          5      None     62.170.2.205  2018-04-08 07:19:26  GMT-0700
# 5          6      None    108.41.39.187  2018-04-08 07:53:03  GMT-0700
# 6          7      None    74.208.182.37  2018-04-08 09:00:47  GMT-0700
# 7          8      None   46.229.164.102  2018-04-08 09:58:37  GMT-0700
# 8          9      None    96.57.208.218  2018-04-08 09:59:37  GMT-0700
# 9         10      None    96.57.208.218  2018-04-08 09:59:37  GMT-0700
# 10        11      None    96.57.208.218  2018-04-08 09:59:37  GMT-0700
# 11        12      None    96.57.208.218  2018-04-08 09:59:37  GMT-0700
# ...
