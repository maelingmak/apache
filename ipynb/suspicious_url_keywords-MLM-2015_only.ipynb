# %%
import datetime as dt
import numpy as np
import pandas as pd

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///../db/apache.sqlite")
base= automap_base()
base.prepare(engine, reflect=True)
inspector = inspect(engine)
log_table = base.classes.access_response
session = Session(engine)

# %%
date_range_2015 = 'select * from access_response where DateTime like "%2015%"'
date_range_2015_results= pd.read_sql_query(date_range_2015, session.bind)

# %%
date_range_2015_results
# Out:
#           id               ip             DateTime  TimeZone   Method  \
# 0       5428    188.165.15.85  2015-12-20 18:33:11  GMT-0800      GET
# 1       5429      192.99.5.43  2015-12-20 19:22:58  GMT-0800      GET
# 2       5430  212.115.224.115  2015-12-20 19:27:55  GMT-0800      GET
# 3       5431      192.99.5.43  2015-12-20 19:31:34  GMT-0800      GET
# 4       5432    162.209.8.106  2015-12-20 20:01:35  GMT-0800      GET
# 5       5433   103.243.179.90  2015-12-20 20:01:35  GMT-0800      GET
# 6       5434   103.243.179.90  2015-12-20 20:01:40  GMT-0800      GET
# 7       5435     40.77.167.13  2015-12-20 20:15:02  GMT-0800      GET
# 8       5436   123.30.175.210  2015-12-20 20:22:01  GMT-0800      GET
# 9       5437   123.30.175.213  2015-12-20 20:22:07  GMT-0800      GET
# 10      5438   123.57.250.139  2015-12-20 20:24:27  GMT-0800     HEAD
# 11      5439  180.109.108.144  2015-12-20 20:33:05  GMT-0800      GET
# ...

# %%
admin_query = 'select * from access_response where URL like "%admin%" and DateTime like "2015%"'
admin_results = pd.read_sql_query(admin_query, session.bind)

# %%
admin_results
# Out:
#          id               ip             DateTime  TimeZone Method  \
# 0      5477    37.58.122.114  2015-12-21 07:40:26  GMT-0800    GET
# 1      5478    37.58.122.114  2015-12-21 07:40:34  GMT-0800    GET
# 2      5480    37.58.122.114  2015-12-21 07:40:44  GMT-0800    GET
# 3      5481    37.58.122.114  2015-12-21 07:40:54  GMT-0800    GET
# 4      5512    212.49.110.70  2015-12-21 14:41:07  GMT-0800    GET
# 5      5519    185.130.5.207  2015-12-21 16:04:06  GMT-0800    GET
# 6      5520    185.130.5.207  2015-12-21 16:04:13  GMT-0800    GET
# 7      5522    185.130.5.207  2015-12-21 16:04:21  GMT-0800    GET
# 8      5523    185.130.5.207  2015-12-21 16:04:22  GMT-0800    GET
# 9      5524    185.130.5.207  2015-12-21 16:04:25  GMT-0800    GET
# 10     5560   80.255.192.237  2015-12-22 02:41:23  GMT-0800    GET
# 11     5585    216.18.231.50  2015-12-22 09:31:26  GMT-0800    GET
# 12     5590   80.255.192.237  2015-12-22 10:26:51  GMT-0800    GET
# ...

# %%
len(admin_results)
# Out:
# 1510

# %%
setup_query = 'select * from access_response where URL like "%setup%" and DateTime like "2015%"'
setup_results = pd.read_sql_query(setup_query, session.bind)

# %%
setup_results
# Out:
#         id              ip             DateTime  TimeZone Method  \
# 0     5477   37.58.122.114  2015-12-21 07:40:26  GMT-0800    GET
# 1     5478   37.58.122.114  2015-12-21 07:40:34  GMT-0800    GET
# 2     5479   37.58.122.114  2015-12-21 07:40:41  GMT-0800    GET
# 3     5480   37.58.122.114  2015-12-21 07:40:44  GMT-0800    GET
# 4     5481   37.58.122.114  2015-12-21 07:40:54  GMT-0800    GET
# 5     5519   185.130.5.207  2015-12-21 16:04:06  GMT-0800    GET
# 6     5520   185.130.5.207  2015-12-21 16:04:13  GMT-0800    GET
# 7     5521   185.130.5.207  2015-12-21 16:04:17  GMT-0800    GET
# 8     5522   185.130.5.207  2015-12-21 16:04:21  GMT-0800    GET
# 9     5523   185.130.5.207  2015-12-21 16:04:22  GMT-0800    GET
# 10    5524   185.130.5.207  2015-12-21 16:04:25  GMT-0800    GET
# 11    5525   185.130.5.207  2015-12-21 16:04:28  GMT-0800    GET
# 12    5585   216.18.231.50  2015-12-22 09:31:26  GMT-0800    GET
# ...

# %%
len(setup_results)
# Out:
# 436

# %%
login_query = 'select * from access_response where URL like "%login%" and DateTime like "2015%"'
login_results = pd.read_sql_query(login_query, session.bind)

# %%
login_results
# Out:
#         id              ip             DateTime  TimeZone Method  \
# 0     5477   37.58.122.114  2015-12-21 07:40:26  GMT-0800    GET
# 1     5478   37.58.122.114  2015-12-21 07:40:34  GMT-0800    GET
# 2     5479   37.58.122.114  2015-12-21 07:40:41  GMT-0800    GET
# 3     5480   37.58.122.114  2015-12-21 07:40:44  GMT-0800    GET
# 4     5481   37.58.122.114  2015-12-21 07:40:54  GMT-0800    GET
# 5     5519   185.130.5.207  2015-12-21 16:04:06  GMT-0800    GET
# 6     5520   185.130.5.207  2015-12-21 16:04:13  GMT-0800    GET
# 7     5521   185.130.5.207  2015-12-21 16:04:17  GMT-0800    GET
# 8     5522   185.130.5.207  2015-12-21 16:04:21  GMT-0800    GET
# 9     5523   185.130.5.207  2015-12-21 16:04:22  GMT-0800    GET
# 10    5524   185.130.5.207  2015-12-21 16:04:25  GMT-0800    GET
# 11    5525   185.130.5.207  2015-12-21 16:04:28  GMT-0800    GET
# 12    5585   216.18.231.50  2015-12-22 09:31:26  GMT-0800    GET
# ...

# %%
len(login_results)
# Out:
# 436

# %%
test_query = 'select * from access_response where URL like "%test%" and DateTime like "2015%"'
test_results = pd.read_sql_query(test_query, session.bind)

# %%
len(test_results)
# Out:
# 526

# %%
test_results
# Out:
#         id              ip             DateTime  TimeZone   Method  \
# 0     5442   188.68.224.62  2015-12-20 20:54:46  GMT-0800      GET
# 1     5445   188.68.224.62  2015-12-20 22:06:50  GMT-0800      GET
# 2     5463   188.68.224.62  2015-12-21 03:04:11  GMT-0800      GET
# 3     5464   188.68.224.62  2015-12-21 03:04:19  GMT-0800      GET
# 4     5472   188.68.224.62  2015-12-21 05:34:01  GMT-0800      GET
# 5     5473   188.68.224.62  2015-12-21 06:07:26  GMT-0800      GET
# 6     5474   188.68.224.62  2015-12-21 06:43:24  GMT-0800      GET
# 7     5489   188.68.224.62  2015-12-21 09:31:12  GMT-0800      GET
# 8     5492   188.68.224.62  2015-12-21 10:27:59  GMT-0800      GET
# 9     5510   188.68.224.62  2015-12-21 14:14:31  GMT-0800      GET
# 10    5528   188.68.224.62  2015-12-21 17:22:07  GMT-0800      GET
# 11    5532   188.68.224.62  2015-12-21 18:18:54  GMT-0800      GET
# 12    5549   188.68.224.62  2015-12-22 00:21:14  GMT-0800      GET
# ...

# %%
login_query = 'select * from access_response where URL like "%login%" and DateTime like "2015%"'
login_results = pd.read_sql_query(login_query, session.bind)

# %%
login_results
# Out:
#         id               ip             DateTime  TimeZone Method  \
# 0     5509    195.242.80.26  2015-12-21 13:35:08  GMT-0800    GET
# 1     5511    212.49.110.70  2015-12-21 14:40:12  GMT-0800    GET
# 2     5866  195.154.199.128  2015-12-14 06:17:04  GMT-0800    GET
# 3     5867  195.154.199.128  2015-12-14 06:17:04  GMT-0800    GET
# 4     5882  195.154.199.128  2015-12-14 09:43:01  GMT-0800    GET
# 5     5883  195.154.199.128  2015-12-14 09:43:01  GMT-0800    GET
# 6     6014   221.132.39.132  2015-12-15 21:10:20  GMT-0800    GET
# 7     6457  180.150.227.242  2015-12-06 13:46:29  GMT-0800    GET
# 8     6458  180.150.227.242  2015-12-06 13:46:29  GMT-0800    GET
# 9     6560   37.146.165.248  2015-12-07 15:24:14  GMT-0800    GET
# 10    6561   37.146.165.248  2015-12-07 15:24:50  GMT-0800    GET
# 11    6573    176.9.139.131  2015-12-07 17:42:57  GMT-0800    GET
# 12    6597   37.146.165.248  2015-12-07 23:46:30  GMT-0800    GET
# ...

# %%
len(login_results)
# Out:
# 689

# %%
ramble_query = 'select * from access_response where URL like "%ramble%" and DateTime like "2015%"'
ramble_results = pd.read_sql_query(ramble_query, session.bind)

# %%
ramble_results
# Out:
#          id               ip             DateTime  TimeZone Method  \
# 0      5429      192.99.5.43  2015-12-20 19:22:58  GMT-0800    GET
# 1      5431      192.99.5.43  2015-12-20 19:31:34  GMT-0800    GET
# 2      5432    162.209.8.106  2015-12-20 20:01:35  GMT-0800    GET
# 3      5433   103.243.179.90  2015-12-20 20:01:35  GMT-0800    GET
# 4      5439  180.109.108.144  2015-12-20 20:33:05  GMT-0800    GET
# 5      5446   107.161.83.151  2015-12-20 22:13:53  GMT-0800    GET
# 6      5448   37.115.187.114  2015-12-20 23:15:58  GMT-0800    GET
# 7      5449   37.115.187.114  2015-12-20 23:16:23  GMT-0800    GET
# 8      5452    66.249.79.233  2015-12-20 23:25:59  GMT-0800    GET
# 9      5453     87.98.216.67  2015-12-20 23:37:25  GMT-0800    GET
# 10     5455   103.27.238.252  2015-12-20 23:51:45  GMT-0800    GET
# 11     5458    66.249.79.240  2015-12-21 00:40:00  GMT-0800    GET
# 12     5459    66.249.79.226  2015-12-21 00:40:05  GMT-0800    GET
# ...

# %%
len(ramble_results)
# Out:
# 4055

# %%
port_query = 'select * from access_response where URL like "%port%" and DateTime like "2015%"'
port_results = pd.read_sql_query(port_query, session.bind)

# %%
port_results
# Out:
#        id              ip             DateTime  TimeZone Method  \
# 0    7760    71.80.209.68  2015-12-03 21:08:03  GMT-0800    GET
# 1   10482   195.154.188.9  2015-11-20 18:47:13  GMT-0800    GET
# 2   12668   188.124.17.47  2015-11-03 17:02:50  GMT-0800    GET
# 3   12756  208.115.113.82  2015-11-04 04:58:44  GMT-0800    GET
# 4   13947   109.252.17.89  2015-10-28 21:29:56  GMT-0700    GET
# 5   14320   183.60.244.46  2015-10-30 22:31:46  GMT-0700    GET
# 6   14321   183.60.244.46  2015-10-30 22:31:46  GMT-0700    GET
# 7   16298  183.60.243.189  2015-10-09 06:23:41  GMT-0700    GET
# 8   16299  183.60.243.189  2015-10-09 06:23:41  GMT-0700    GET
# 9   17238   46.119.124.35  2015-09-21 01:16:43  GMT-0700    GET
# 10  17306  217.66.157.105  2015-09-22 07:30:26  GMT-0700    GET
# 11  17330   46.119.124.35  2015-09-22 12:50:16  GMT-0700    GET
# 12  17526  178.191.172.35  2015-09-25 18:06:56  GMT-0700    GET
# 13  17990     23.94.29.35  2015-09-19 21:54:52  GMT-0700    GET
# ...

# %%
len(port_results)
# Out:
# 28

# %%
ua_script_query = 'select * from access_response where UserAgent like "%urll%" or UserAgent like "%curl%" and DateTime like "2015%"'
ua_script_results = pd.read_sql_query(ua_script_query, session.bind)

# %%
len(ua_script_results)
# Out:
# 658

# %%
ua_script_results
# Out:
#         id               ip             DateTime  TimeZone Method  \
# 0       26    24.48.238.249  2018-04-08 13:10:40  GMT-0700    GET
# 1       27    24.48.238.249  2018-04-08 13:35:08  GMT-0700    GET
# 2       55    114.147.72.16  2018-04-09 01:11:06  GMT-0700    GET
# 3      136  135.245.115.103  2018-04-10 13:03:14  GMT-0700    GET
# 4      167    114.147.72.16  2018-04-11 01:10:29  GMT-0700    GET
# 5      224  140.116.245.162  2018-04-11 14:56:07  GMT-0700    GET
# 6      270    128.62.160.14  2018-04-12 15:45:44  GMT-0700    GET
# 7      282  119.247.135.127  2018-04-13 01:55:00  GMT-0700    GET
# 8      560   103.81.106.250  2018-04-03 04:44:33  GMT-0700    GET
# 9      668  181.140.168.184  2018-04-04 12:29:52  GMT-0700    GET
# 10     673  181.140.168.184  2018-04-04 13:11:15  GMT-0700    GET
# 11     677  181.140.168.184  2018-04-04 13:47:25  GMT-0700    GET
# 12     678  181.140.168.184  2018-04-04 14:11:09  GMT-0700    GET
# ...

# %%
ua_script_results_no_cat = ua_script_results[(ua_script_results.URL != '/phone_pix/cat.jpg')]

# %%
ua_script_results_no_cat
# Out:
#         id               ip             DateTime  TimeZone Method  \
# 20    2064  134.119.216.241  2018-03-20 23:17:46  GMT-0700    GET
# 37    3822    51.255.82.192  2018-03-01 20:30:53  GMT-0800    GET
# 38    3823    51.255.82.192  2018-03-01 20:30:54  GMT-0800    GET
# 39    3824    51.255.82.192  2018-03-01 20:30:54  GMT-0800    GET
# 40    3825    51.255.82.192  2018-03-01 20:30:54  GMT-0800    GET
# 41    3826    51.255.82.192  2018-03-01 20:30:55  GMT-0800    GET
# 42    3827    51.255.82.192  2018-03-01 20:30:56  GMT-0800    GET
# 43    3828    51.255.82.192  2018-03-01 20:30:56  GMT-0800    GET
# 44    3829    51.255.82.192  2018-03-01 20:30:56  GMT-0800    GET
# 45    3830    51.255.82.192  2018-03-01 20:30:57  GMT-0800    GET
# 46    3831    51.255.82.192  2018-03-01 20:30:57  GMT-0800    GET
# 47    3832    51.255.82.192  2018-03-01 20:30:57  GMT-0800    GET
# 48    3833    51.255.82.192  2018-03-01 20:30:58  GMT-0800    GET
# ...

# %%
len(ua_script_results_no_cat)
# Out:
# 572
